# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\shashi\Downloads\IRIS.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
setosa = df[df['species'] == 'Iris-setosa']

# %%
setosa.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
versicolor = df[df['species'] == 'Iris-versicolor']

# %%
versicolor.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor

# %%
virginica = df[df['species'] == 'Iris-virginica']

# %%
virginica.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
setosa.shape
# Out:
# (50, 5)

# %%
versicolor.shape
# Out:
# (50, 5)

# %%
virginica.shape
# Out:
# (50, 5)

# %%
sns.histplot(setosa['sepal_length'],color = 'purple')
plt.show()

# %%
sns.histplot(setosa['sepal_width'],color = 'purple')
plt.show()

# %%
sns.histplot(setosa['petal_length'],color = 'purple')
plt.show()

# %%
sns.histplot(setosa['petal_width'],color = 'purple')
plt.show()

# %%
setosa.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000

# %%
sns.histplot(versicolor['sepal_length'],color = 'red')
plt.show()

# %%
sns.histplot(versicolor['sepal_width'],color = 'red')
plt.show()

# %%
sns.histplot(versicolor['petal_length'],color = 'red')
plt.show()

# %%
sns.histplot(versicolor['petal_width'],color = 'red')
plt.show()

# %%
versicolor.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
setosa.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000

# %%
sns.histplot(virginica['sepal_length'])
plt.show()

# %%
sns.histplot(virginica['sepal_width'])
plt.show()

# %%
sns.histplot(virginica['petal_length'])
plt.show()

# %%
sns.histplot(virginica['petal_width'])
plt.show()

# %%
virginica.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
versicolor.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
# Decision Tree Implementation

# %%
df.head()   # Display the first few rows of the dataset
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Split the dataset into features and target

# %%
x = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df['species']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text

# %%
# Create and train the Decision Tree Classifier

# %%
dt_model = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=42)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
y_pred = dt_model.predict(X_test)   # Make predictions

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
# Evaluate the model

# %%
print("\nModel Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Model Accuracy: 1.0

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %%
plt.figure(figsize=(15, 10))
plot_tree(dt_model, feature_names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], 
          class_names=iris_data.target_names, filled=True, rounded=True)
plt.title("Decision Tree Visualization")
plt.show()

# %%
# Export the decision tree rules

# %%
tree_rules = export_text(dt_model, feature_names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
print("\nDecision Tree Rules:\n", tree_rules)
# Out:
# Decision Tree Rules:
#  |--- petal_length <= 2.45
# |   |--- class: Iris-setosa
# |--- petal_length >  2.45
# |   |--- petal_length <= 4.75
# |   |   |--- petal_width <= 1.60
# |   |   |   |--- class: Iris-versicolor
# |   |   |--- petal_width >  1.60
# |   |   |   |--- class: Iris-virginica
# |   |--- petal_length >  4.75
# |   |   |--- petal_width <= 1.75
# |   |   |   |--- class: Iris-versicolor
# |   |   |--- petal_width >  1.75
# |   |   |   |--- class: Iris-virginica
